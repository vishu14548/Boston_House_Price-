# %% [markdown]
# # Importing libraries

# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_boston
from sklearn.model_selection import train_test_split
from sklearn import linear_model
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Loading DATA

# %%
data=load_boston()
print(data)
# Out:
# {'data': array([[6.3200e-03, 1.8000e+01, 2.3100e+00, ..., 1.5300e+01, 3.9690e+02,
#         4.9800e+00],
#        [2.7310e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9690e+02,
#         9.1400e+00],
#        [2.7290e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9283e+02,
#         4.0300e+00],
#        ...,
#        [6.0760e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         5.6400e+00],
#        [1.0959e-01, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9345e+02,
#         6.4800e+00],
#        [4.7410e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         7.8800e+00]]), 'target': array([24. , 21.6, 34.7, 33.4, 36.2, 28.7, 22.9, 27.1, 16.5, 18.9, 15. ,
#        18.9, 21.7, 20.4, 18.2, 19.9, 23.1, 17.5, 20.2, 18.2, 13.6, 19.6,
#        15.2, 14.5, 15.6, 13.9, 16.6, 14.8, 18.4, 21. , 12.7, 14.5, 13.2,
#        13.1, 13.5, 18.9, 20. , 21. , 24.7, 30.8, 34.9, 26.6, 25.3, 24.7,
#        21.2, 19.3, 20. , 16.6, 14.4, 19.4, 19.7, 20.5, 25. , 23.4, 18.9,
# ...

# %% [markdown]
# # Features in DATASET

# %%
print(data.feature_names)
# Out:
# ['CRIM' 'ZN' 'INDUS' 'CHAS' 'NOX' 'RM' 'AGE' 'DIS' 'RAD' 'TAX' 'PTRATIO'
#  'B' 'LSTAT']

# %% [markdown]
# # Forming DATAFRAME

# %%
dfe_x=pd.DataFrame(boston.data, columns=boston.feature_names)
dfe_y=pd.DataFrame(boston.target)

# %%
dfe_x.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %%
dfe_y
# Out:
#         0
# 0    24.0
# 1    21.6
# 2    34.7
# 3    33.4
# 4    36.2
# ..    ...
# 501  22.4
# 502  20.6
# 503  23.9
# 504  22.0
# 505  11.9
#
# [506 rows x 1 columns]

# %% [markdown]
# # Splitting DATA into TRAIN and TEST

# %%
x_train, x_test, y_train, y_test = train_test_split(df_x, df_y, test_size=0.30, random_state=51)

# %% [markdown]
# # Initializing Linear Regression MODEL

# %%
regression=linear_model.LinearRegression()

# %% [markdown]
# # Model Training

# %%
regression.fit(x_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # Predictions Made by MODEL

# %%
y_pred=regression.predict(x_test)
print(y_pred)
# Out:
# [[14.23169147]
#  [14.13088626]
#  [40.95629814]
#  [20.48284599]
#  [21.35903935]
#  [19.55029529]
#  [40.61736152]
#  [14.03954713]
#  [24.58703148]
#  [17.86351223]
#  [29.57746643]
#  [35.48044386]
#  [21.14526352]
#  [13.44365282]
#  [11.85537315]
#  [36.74698807]
#  [21.29756914]
#  [16.4018443 ]
#  [20.23263981]
#  [16.86086223]
#  [15.58398861]
#  [22.32261905]
#  [36.49686547]
#  [23.7119976 ]
#  [10.2893021 ]
#  [27.73932264]
#  [18.45294785]
#  [ 9.49833489]
#  [ 3.07291803]
#  [23.17656039]
#  [ 8.0547866 ]
#  [17.17619021]
#  [21.10205537]
#  [20.79144085]
#  [21.30497993]
#  [ 5.52215443]
#  [16.46032817]
#  [20.49241493]
#  [20.8032875 ]
#  [34.70778231]
#  [32.80122133]
#  [20.39983046]
#  [30.98941698]
#  [20.24931345]
#  [24.5082099 ]
#  [19.64255225]
#  [28.29952806]
#  [20.80815675]
#  [24.49024378]
#  [33.15752055]
#  [28.64773429]
#  [13.80954195]
#  [19.38082523]
#  [34.7022023 ]
#  [24.05214831]
#  [34.60746565]
#  [19.79848262]
#  [18.76905195]
# ...

# %% [markdown]
# # Actual Values

# %%
y_test=np.array(y_test)
print(y_test)
# Out:
# [[11.5]
#  [11. ]
#  [50. ]
#  [23. ]
#  [21.1]
#  [18.5]
#  [48.5]
#  [14.5]
#  [28.1]
#  [17.8]
#  [32.9]
#  [50. ]
#  [21. ]
#  [11.3]
#  [12. ]
#  [36. ]
#  [22.7]
#  [ 8.5]
#  [16.8]
#  [19.5]
#  [23.1]
#  [26.6]
#  [44. ]
#  [23. ]
#  [ 8.3]
#  [22.3]
#  [12.6]
#  [23.7]
#  [ 8.8]
#  [16.5]
#  [11.9]
#  [10.2]
#  [20.6]
#  [19.6]
#  [20.7]
#  [ 7.4]
#  [10.4]
#  [20.3]
#  [22. ]
#  [43.8]
#  [33.1]
#  [19.2]
#  [24.8]
#  [20.4]
#  [24.7]
#  [14.6]
#  [27.1]
#  [27.1]
#  [20.5]
#  [31.5]
#  [22. ]
#  [13.3]
#  [16.4]
#  [33.4]
#  [25. ]
#  [31. ]
#  [19.6]
#  [18.3]
#  [37.9]
#  [18.6]
#  [20.5]
#  [12.8]
#  [33.1]
#  [22.8]
#  [18.1]
#  [20.6]
#  [24.5]
#  [29.1]
#  [29.8]
#  [17.3]
#  [25.3]
#  [14.5]
#  [18.5]
#  [19.9]
#  [27.5]
#  [11.8]
#  [24. ]
#  [18.4]
#  [17.4]
#  [50. ]
#  [36.5]
#  [23.2]
#  [17.5]
#  [45.4]
#  [15.7]
#  [50. ]
#  [10.9]
#  [26.5]
#  [19. ]
#  [20.8]
#  [30.8]
#  [19.4]
#  [21.9]
#  [13.4]
#  [21.8]
#  [22.5]
#  [35.1]
#  [23.3]
#  [27.5]
#  [24.4]
# ...

# %% [markdown]
# # Representing Data on Graph

# %%
plt.figure(figsize=(14,10))
plt.scatter(y_test,y_pred)
plt.plot([0,50],[0,50],'r')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Graph of Predicted Values v/s Actual values')
# Out:
# Text(0.5, 1.0, 'Graph of Predicted Values v/s Actual values')
